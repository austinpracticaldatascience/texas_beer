# %%
# Import Pandas
import pandas as pd

# Read the csv
df = pd.read_csv('Mixed_Beverage_Gross_Receipts.csv')

# %%
def df_info_col(df):
    
    # Get info of dataframe
    print(df.info())
    
    #Explore columns
    print(df.columns)
    
df_info_col(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2788501 entries, 0 to 2788500
# Data columns (total 24 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Taxpayer Number             int64
#  1   Taxpayer Name               object
#  2   Taxpayer Address            object
#  3   Taxpayer City               object
#  4   Taxpayer State              object
#  5   Taxpayer Zip                float64
#  6   Taxpayer County             int64
#  7   Location Number             int64
#  8   Location Name               object
#  9   Location Address            object
#  10  Location City               object
#  11  Location State              object
#  12  Location Zip                int64
#  13  Location County             int64
#  14  Inside/Outside City Limits  object
#  15  TABC Permit Number          object
#  16  Responsibility Begin Date   object
#  17  Responsibility End Date     object
#  18  Obligation End Date         object
#  19  Liquor Receipts             int64
#  20  Wine Receipts               int64
#  21  Beer Receipts               int64
#  22  Cover Charge Receipts       int64
#  23  Total Receipts              int64
# dtypes: float64(1), int64(10), object(13)
# memory usage: 510.6+ MB
# None
# Index(['Taxpayer Number', 'Taxpayer Name', 'Taxpayer Address', 'Taxpayer City',
#        'Taxpayer State', 'Taxpayer Zip', 'Taxpayer County', 'Location Number',
#        'Location Name', 'Location Address', 'Location City', 'Location State',
#        'Location Zip', 'Location County', 'Inside/Outside City Limits',
#        'TABC Permit Number', 'Responsibility Begin Date',
#        'Responsibility End Date', 'Obligation End Date', 'Liquor Receipts',
#        'Wine Receipts', 'Beer Receipts', 'Cover Charge Receipts',
#        'Total Receipts'],
#       dtype='object')

# %%
def timestamp(df,col):
    
    # convert to datetime
    df[col] = pd.to_datetime(df[col])

    # Updated info
    print(df.info())
    
timestamp(df,"Responsibility Begin Date")
timestamp(df,"Responsibility End Date")
timestamp(df,"Obligation End Date")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2788501 entries, 0 to 2788500
# Data columns (total 24 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Taxpayer Number             int64
#  1   Taxpayer Name               object
#  2   Taxpayer Address            object
#  3   Taxpayer City               object
#  4   Taxpayer State              object
#  5   Taxpayer Zip                float64
#  6   Taxpayer County             int64
#  7   Location Number             int64
#  8   Location Name               object
#  9   Location Address            object
#  10  Location City               object
#  11  Location State              object
#  12  Location Zip                int64
#  13  Location County             int64
#  14  Inside/Outside City Limits  object
#  15  TABC Permit Number          object
#  16  Responsibility Begin Date   datetime64[ns]
#  17  Responsibility End Date     object
#  18  Obligation End Date         object
#  19  Liquor Receipts             int64
#  20  Wine Receipts               int64
#  21  Beer Receipts               int64
#  22  Cover Charge Receipts       int64
#  23  Total Receipts              int64
# dtypes: datetime64[ns](1), float64(1), int64(10), object(12)
# memory usage: 510.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2788501 entries, 0 to 2788500
# Data columns (total 24 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Taxpayer Number             int64
#  1   Taxpayer Name               object
#  2   Taxpayer Address            object
#  3   Taxpayer City               object
#  4   Taxpayer State              object
#  5   Taxpayer Zip                float64
#  6   Taxpayer County             int64
#  7   Location Number             int64
#  8   Location Name               object
#  9   Location Address            object
#  10  Location City               object
#  11  Location State              object
#  12  Location Zip                int64
#  13  Location County             int64
#  14  Inside/Outside City Limits  object
#  15  TABC Permit Number          object
#  16  Responsibility Begin Date   datetime64[ns]
#  17  Responsibility End Date     datetime64[ns]
#  18  Obligation End Date         object
#  19  Liquor Receipts             int64
#  20  Wine Receipts               int64
#  21  Beer Receipts               int64
#  22  Cover Charge Receipts       int64
#  23  Total Receipts              int64
# dtypes: datetime64[ns](2), float64(1), int64(10), object(11)
# memory usage: 510.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2788501 entries, 0 to 2788500
# Data columns (total 24 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Taxpayer Number             int64
#  1   Taxpayer Name               object
#  2   Taxpayer Address            object
#  3   Taxpayer City               object
#  4   Taxpayer State              object
#  5   Taxpayer Zip                float64
#  6   Taxpayer County             int64
#  7   Location Number             int64
#  8   Location Name               object
#  9   Location Address            object
#  10  Location City               object
#  11  Location State              object
#  12  Location Zip                int64
#  13  Location County             int64
#  14  Inside/Outside City Limits  object
#  15  TABC Permit Number          object
#  16  Responsibility Begin Date   datetime64[ns]
#  17  Responsibility End Date     datetime64[ns]
#  18  Obligation End Date         datetime64[ns]
#  19  Liquor Receipts             int64
#  20  Wine Receipts               int64
#  21  Beer Receipts               int64
#  22  Cover Charge Receipts       int64
#  23  Total Receipts              int64
# dtypes: datetime64[ns](3), float64(1), int64(10), object(10)
# memory usage: 510.6+ MB
# None

# %%
timestamp(df,"Responsibility End Date")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2788501 entries, 0 to 2788500
# Data columns (total 24 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Taxpayer Number             int64
#  1   Taxpayer Name               object
#  2   Taxpayer Address            object
#  3   Taxpayer City               object
#  4   Taxpayer State              object
#  5   Taxpayer Zip                float64
#  6   Taxpayer County             int64
#  7   Location Number             int64
#  8   Location Name               object
#  9   Location Address            object
#  10  Location City               object
#  11  Location State              object
#  12  Location Zip                int64
#  13  Location County             int64
#  14  Inside/Outside City Limits  object
#  15  TABC Permit Number          object
#  16  Responsibility Begin Date   datetime64[ns]
#  17  Responsibility End Date     datetime64[ns]
#  18  Obligation End Date         datetime64[ns]
#  19  Liquor Receipts             int64
#  20  Wine Receipts               int64
#  21  Beer Receipts               int64
#  22  Cover Charge Receipts       int64
#  23  Total Receipts              int64
# dtypes: datetime64[ns](3), float64(1), int64(10), object(10)
# memory usage: 510.6+ MB
# None

# %%
df = df.sort_values(by=['Obligation End Date'])
df.tail(4)
# Out:
#          Taxpayer Number                   Taxpayer Name  \
# 2772032      32076544355           RAINBOW LONGVIEW INC.
# 2766957      32068645731  NICKS CRAWFISH BAR CORPORATION
# 778174       32080328233              FRENCH COWBOY, LLC
# 2778282      17522587025            RED MESA GRILL, INC.
#
#                  Taxpayer Address Taxpayer City Taxpayer State  Taxpayer Zip  \
# 2772032              6915 FM 31 S      CARTHAGE             TX       75633.0
# 2766957  4025 HIGHWAY 6 N STE 107       HOUSTON             TX       77084.0
# 778174    611 SHEPHERD DR APT 145       HOUSTON             TX       77007.0
# 2778282               PO BOX 6571      MCKINNEY             TX       75071.0
#
#          Taxpayer County  Location Number          Location Name  \
# 2772032              183                1  RAINBOW LONGVIEW INC.
# 2766957              101                1    NICK'S CRAWFISH BAR
# 778174               101                1          CAFE PHILIPPE
# 2778282               43                1         RED MESA GRILL
#
#                  Location Address  ... Inside/Outside City Limits  \
# 2772032             203 S HIGH ST  ...                          Y
# 2766957  4025 HIGHWAY 6 N STE 107  ...                          Y
# 778174          1830 W ALABAMA ST  ...                          Y
# 2778282           2401 S GREGG ST  ...                          Y
#
#         TABC Permit Number  Responsibility Begin Date  \
# 2772032          N 1112119                 2021-03-12
# 2766957          MB1042253                 2019-01-15
# 778174         MB200042829                 2021-11-30
# 2778282           MB238149                 1993-11-30
#
#          Responsibility End Date Obligation End Date Liquor Receipts  \
# 2772032                      NaT          2022-08-31               0
# 2766957               2022-08-02          2022-08-31               0
# 778174                       NaT          2022-08-31               0
# 2778282                      NaT          2022-08-31               0
#
#         Wine Receipts Beer Receipts Cover Charge Receipts  Total Receipts
# 2772032             0             0                     0               0
# 2766957             0             0                     0               0
# 778174              0             0                     0               0
# 2778282             0             0                     0               0
#
# [4 rows x 24 columns]

# %%
def shape_inspect(dframe):
    
    # Print dataframe shape
    print("The shape of the DataFrame is:", df.shape)
    
    # Skip a line
    print("\n")

    # Inspect data
    return df.head(4)

shape_inspect(df)
# Out:
# The shape of the DataFrame is: (2788501, 24)
#    Taxpayer Number                       Taxpayer Name  \
# 0      32047970895        HONDURAS MAYA CAFE & BAR LLC
# 1      32049923835  MERMAID KARAOKE PRIVATE CLUB, INC.
# 2      32034036304                FENG KAI CORPORATION
# 3      14537211071               THE HUTTO SMITHS, LLC
#
#               Taxpayer Address  Taxpayer City Taxpayer State  Taxpayer Zip  \
# 0                8011 HAZEN ST        HOUSTON             TX       77036.0
# 1  2639 WALNUT HILL LN STE 225         DALLAS             TX       75229.0
# 2            8427 BOULEVARD 26  N RICHLND HLS             TX       76180.0
# 3           429 LITTLE LAKE RD          HUTTO             TX       78634.0
#
#    Taxpayer County  Location Number                 Location Name  \
# 0              101                1  HONDURAS MAYA CAFE & BAR LLC
# 1               57                1  MERMAID KARAOKE PRIVATE CLUB
# 2              220                1                JAPANESE GRILL
# 3              246                1     THE DOWNTOWN HALL OF FAME
#
#              Location Address  ... Inside/Outside City Limits  \
# 0    5945 BELLAIRE BLVD STE B  ...                          Y
# 1  1310 W CAMPBELL RD STE 103  ...                          Y
# 2           8427 BOULEVARD 26  ...                          Y
# 3                 205 EAST ST  ...                          Y
#
#   TABC Permit Number  Responsibility Begin Date  Responsibility End Date  \
# 0           MB817033                 08/16/2012               09/12/2019
# 1           N 837378                 04/12/2013               07/01/2015
# 2           MB576670                 05/01/2008               03/17/2018
# 3           MB791778                 12/06/2011                      NaN
#
#   Obligation End Date Liquor Receipts Wine Receipts Beer Receipts  \
# 0          07/31/2019               0             0             0
# 1          08/31/2014             480           185          1374
# 2          06/30/2016            1143           167           669
# 3          03/31/2018           12881           357         10447
#
#   Cover Charge Receipts  Total Receipts
# 0                     0               0
# 1                     0            2039
# 2                     0            1979
# 3                     0           23685
#
# [4 rows x 24 columns]

# %%
def null_sum():

    # Check if there are any null values
    total = df.isnull().sum().sort_values(ascending=False)
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    x = missing.head()
    
    return x
    
null_sum()
# Out:
#                            Total   Percent
# Responsibility End Date  1657846  0.594529
# Taxpayer State               973  0.000349
# Taxpayer Zip                 973  0.000349
# Taxpayer Number                0  0.000000
# Location County                0  0.000000

# %%
# Focus on Austin
df_aus = df[df['Taxpayer County'] == 227]

# %%
def shape_inspect(df):
    
    # Print dataframe shape
    print("The shape of the DataFrame is:", df.shape)
    
    # Skip a line
    print("\n")

    # Inspect data
    x = df.head(4)
    
    return x

shape_inspect(df_aus)
# Out:
# The shape of the DataFrame is: (170554, 24)
#     Taxpayer Number                   Taxpayer Name  \
# 8       32045673145       FINE WINE MANAGEMENT, LLC
# 17      32045673145       FINE WINE MANAGEMENT, LLC
# 25      32041933782            SAI SEVEN HILLS, LLC
# 35      17429812450  PETES MANAGEMENT ADDISON, INC.
#
#                      Taxpayer Address Taxpayer City Taxpayer State  \
# 8   4705 SPICEWOOD SPRINGS RD STE 200        AUSTIN             TX
# 17  4705 SPICEWOOD SPRINGS RD STE 200        AUSTIN             TX
# 25             300 S LAMAR BLVD STE A        AUSTIN             TX
# 35               413 ROLLING GREEN DR       LAKEWAY             TX
#
#     Taxpayer Zip  Taxpayer County  Location Number  \
# 8        78759.0              227                4
# 17       78759.0              227                4
# 25       78704.0              227                1
# 35       78734.0              227                1
#
#                              Location Name           Location Address  ...  \
# 8               BOB'S STEAK AND CHOP HOUSE    1700 RESEARCH FOREST DR  ...
# 17              BOB'S STEAK AND CHOP HOUSE    1700 RESEARCH FOREST DR  ...
# 25  FLOUR AND VINE RESTAURANT AND WINE BAR     300 S LAMAR BLVD STE A  ...
# 35                    PETES DUELING PIANOS  4980 BELT LINE RD STE 200  ...
#
#    Inside/Outside City Limits TABC Permit Number  Responsibility Begin Date  \
# 8                           Y           MB857071                 11/13/2013
# 17                          Y           MB857071                 11/13/2013
# 25                          Y           MB769003                 02/28/2011
# 35                          Y           MB488522                 03/02/2001
#
#     Responsibility End Date Obligation End Date Liquor Receipts Wine Receipts  \
# 8                04/16/2018          01/31/2014           10853         25320
# 17               04/16/2018          05/31/2014           33159         92252
# 25               08/24/2018          07/31/2011           12590          1175
# 35                      NaN          11/30/2018           88311          1768
#
#    Beer Receipts Cover Charge Receipts  Total Receipts
# 8            712                     0           36885
# 17          3560                     0          128971
# 25          3079                     0           16844
# 35         27978                     0          118057
#
# [4 rows x 24 columns]

# %%
# Focus on Houston
df_hou = df[df['Taxpayer County'] == 101]

# %%
shape_inspect(df_hou)
# Out:
# The shape of the DataFrame is: (436463, 24)
#     Taxpayer Number                   Taxpayer Name        Taxpayer Address  \
# 0       32047970895    HONDURAS MAYA CAFE & BAR LLC           8011 HAZEN ST
# 6       32039541860               GREEN GINGER INC.          1574 W GRAY ST
# 13      32039762029               LT BUSINESS, INC.  12350 SHADOW ISLAND DR
# 18      32051085341  HORSERADISH MAYONNAISE, L.L.C.    6412 N MAIN ST STE C
#
#    Taxpayer City Taxpayer State  Taxpayer Zip  Taxpayer County  \
# 0        HOUSTON             TX       77036.0              101
# 6        HOUSTON             TX       77019.0              101
# 13       HOUSTON             TX       77082.0              101
# 18       HOUSTON             TX       77009.0              101
#
#     Location Number                 Location Name          Location Address  \
# 0                 1  HONDURAS MAYA CAFE & BAR LLC  5945 BELLAIRE BLVD STE B
# 6                 1                   CAFE GINGER            1952 W GRAY ST
# 13                1            LE VIET RESTAURANT      11328A WESTHEIMER RD
# 18                1                       LEI LOW      6412 N MAIN ST STE C
#
#     ... Inside/Outside City Limits TABC Permit Number  \
# 0   ...                          Y           MB817033
# 6   ...                          Y           MB734102
# 13  ...                          Y           MB517825
# 18  ...                          Y           MB850404
#
#     Responsibility Begin Date  Responsibility End Date Obligation End Date  \
# 0                  08/16/2012               09/12/2019          07/31/2019
# 6                  10/13/2009               04/18/2018          08/31/2010
# 13                 03/01/2010               03/14/2018          01/31/2016
# 18                 08/30/2013                      NaN          05/31/2020
#
#    Liquor Receipts Wine Receipts Beer Receipts Cover Charge Receipts  \
# 0                0             0             0                     0
# 6             2834          7986           957                     0
# 13             125             0           250                     0
# 18           21723             0             0                     0
#
#     Total Receipts
# 0                0
# 6            11777
# 13             375
# 18           21723
#
# [4 rows x 24 columns]

# %%
# Focus on DFW
df_dfw = df[(df['Taxpayer County'] == 57) | (df['Taxpayer County'] == 220)]

# %%
shape_inspect(df_dfw)
# Out:
# The shape of the DataFrame is: (609413, 24)
#     Taxpayer Number                       Taxpayer Name  \
# 1       32049923835  MERMAID KARAOKE PRIVATE CLUB, INC.
# 2       32034036304                FENG KAI CORPORATION
# 5       17561523097             GARLAND ELKS CLUB, INC.
# 11      30116278331     THE HARBOR POINT CLUB AND GRILL
#
#                Taxpayer Address  Taxpayer City Taxpayer State  Taxpayer Zip  \
# 1   2639 WALNUT HILL LN STE 225         DALLAS             TX       75229.0
# 2             8427 BOULEVARD 26  N RICHLND HLS             TX       76180.0
# 5                 PO BOX 494978        GARLAND             TX       75049.0
# 11           2121 BUCKINGHAM RD     RICHARDSON             TX       75081.0
#
#     Taxpayer County  Location Number                  Location Name  \
# 1                57                1   MERMAID KARAOKE PRIVATE CLUB
# 2               220                1                 JAPANESE GRILL
# 5                57                1          B P O E GARLAND #1984
# 11               57                2  THE HARBOR POINT CLUB & GRILL
#
#               Location Address  ... Inside/Outside City Limits  \
# 1   1310 W CAMPBELL RD STE 103  ...                          Y
# 2            8427 BOULEVARD 26  ...                          Y
# 5           3825 DUCK CREEK DR  ...                          Y
# 11          2121 BUCKINGHAM RD  ...                          Y
#
#    TABC Permit Number  Responsibility Begin Date  Responsibility End Date  \
# 1            N 837378                 04/12/2013               07/01/2015
# 2            MB576670                 05/01/2008               03/17/2018
# 5            NE482712                 11/02/2000                      NaN
# 11           N 206013                 10/31/1995               04/16/2018
#
#    Obligation End Date Liquor Receipts Wine Receipts Beer Receipts  \
# 1           08/31/2014             480           185          1374
# 2           06/30/2016            1143           167           669
# 5           01/31/2015            1674            19          2124
# 11          08/31/2008           16322           510         17958
#
#    Cover Charge Receipts  Total Receipts
# 1                      0            2039
# 2                      0            1979
# 5                      0            3817
# 11                     0           34790
#
# [4 rows x 24 columns]

# %%
# Focus on San Antonio
df_sa = df[df['Taxpayer County'] == 15]

# %%
shape_inspect(df_sa)
# Out:
# The shape of the DataFrame is: (184525, 24)
#      Taxpayer Number                         Taxpayer Name  \
# 16       17428720902  MANDO'S RIVER SEAFOOD RESTAURANT INC
# 96       32049153466           JAMAICA JAMAICA CUISINE LLC
# 250      17426545970                  CB RESTAURANTS, INC.
# 253      32008170998                     JOHN WAYNE DOWNUM
#
#           Taxpayer Address Taxpayer City Taxpayer State  Taxpayer Zip  \
# 16      2918 W COMMERCE ST   SAN ANTONIO             TX       78207.0
# 96         2026 AUSTIN HWY   SAN ANTONIO             TX       78218.0
# 250  9510 TIOGA DR STE 102   SAN ANTONIO             TX       78230.0
# 253           PO BOX 15858   SAN ANTONIO             TX       78212.0
#
#      Taxpayer County  Location Number                         Location Name  \
# 16                15                2  MANDO'S RIVER SEAFOOD RESTAURANT INC
# 96                15                3               JAMAICA JAMAICA CUISINE
# 250               15                1                                SUGARS
# 253               15                2                             THE ANNEX
#
#                  Location Address  ... Inside/Outside City Limits  \
# 16             2918 W COMMERCE ST  ...                          Y
# 96   6909 N LOOP 1604 E STE VC09A  ...                          Y
# 250              2731 NW LOOP 410  ...                          Y
# 253             330 SAN PEDRO AVE  ...                          Y
#
#     TABC Permit Number  Responsibility Begin Date  Responsibility End Date  \
# 16            MB650751                 02/06/2007                      NaN
# 96           MB1083222                 03/09/2020                      NaN
# 250           MB437968                 02/01/2001                      NaN
# 253           MB409424                 03/21/1997               03/20/2019
#
#     Obligation End Date Liquor Receipts Wine Receipts Beer Receipts  \
# 16           09/30/2014             891             0          5392
# 96           04/30/2020               0             0             0
# 250          10/31/2015          164240          3169        100933
# 253          10/31/2013           35051           439         17515
#
#     Cover Charge Receipts  Total Receipts
# 16                      0            6283
# 96                      0               0
# 250                     0          268342
# 253                     0           53005
#
# [4 rows x 24 columns]

# %%
def column_uniquevalues(df,col):
    
    # Get unique amount of names for recipes
    x = df[col].nunique()
    
    return x

# %%
# Number of unique location address in Austin
column_uniquevalues(df_aus,'Location Address')
# Out:
# 2322

# %%
# Number of unique location names in Aus
column_uniquevalues(df_aus,'Location Name')
# Out:
# 2296

# %%
# Number of unique location address in SA
column_uniquevalues(df_sa,'Location Address')
# Out:
# 2123

# %%
# Number of unique location names in SA
column_uniquevalues(df_sa,'Location Name')
# Out:
# 2167

# %%
# Number of unique location address in DFW
column_uniquevalues(df_dfw,'Location Address')
# Out:
# 7064

# %%
# Number of unique location names in DFW
column_uniquevalues(df_dfw,'Location Name')
# Out:
# 7291

# %%
# Number of unique location address in Houston
column_uniquevalues(df_hou,'Location Address')
# Out:
# 5503

# %%
# Number of unique location names in Houston
column_uniquevalues(df_hou,'Location Name')
# Out:
# 6026

# %%
# Total receipts in Aus
tot_receipt_aus = df_aus['Total Receipts'].sum()

print(tot_receipt_aus)
# Out:
# 8283859669

# %%
# Total receipts in SA
tot_receipt_aus = df_sa['Total Receipts'].sum()

print(tot_receipt_aus)
# Out:
# 6121368030

# %%
# Total receipts in DFW
tot_receipt_aus = df_dfw['Total Receipts'].sum()

print(tot_receipt_aus)
# Out:
# 20517578078

# %%
# Total receipts in Hou
tot_receipt_aus = df_hou['Total Receipts'].sum()

print(tot_receipt_aus)
# Out:
# 17659669479

# %%
dups = df.duplicated(subset=['Taxpayer Number']) #subset=['Taxpayer Number'].sum()

print(dups)
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2788496     True
# 2788497     True
# 2788498     True
# 2788499     True
# 2788500     True
# Length: 2788501, dtype: bool

# %%
df.tail(10)
# Out:
#          Taxpayer Number              Taxpayer Name  \
# 2788491      32048588530             BEANSTALK, LLC
# 2788492      32075388259              TIGER YS, LLC
# 2788493      32053589183               SIMSKIE, LLC
# 2788494      32045900001  COUTURE HOTEL CORPORATION
# 2788495      32004531698        STEPHEN N ZIMMERMAN
# 2788496      32069471368      GORZUGIS SABINAL  LLC
# 2788497      32048588530             BEANSTALK, LLC
# 2788498      32054457521       NEW DONG JIANG, INC.
# 2788499      32066921282         APEX BEVERAGE, LLC
# 2788500      32053574318       DBLT ENTERPRISES LLC
#
#                    Taxpayer Address  Taxpayer City Taxpayer State  \
# 2788491      2950 S JOHN REDDITT DR         LUFKIN             TX
# 2788492                 PO BOX 2474     HARKER HTS             TX
# 2788493                 PO BOX 2346  CRYSTAL BEACH             TX
# 2788494      2803 SAINT ANDREWS CIR          ENNIS             TX
# 2788495          3410 MONTROSE BLVD        HOUSTON             TX
# 2788496               PO BOX 420806        DEL RIO             TX
# 2788497      2950 S JOHN REDDITT DR         LUFKIN             TX
# 2788498  8303 SOUTHWEST FWY STE 760        HOUSTON             TX
# 2788499         952 ECHO LN STE 380        HOUSTON             TX
# 2788500          3760 CARTWRIGHT RD  MISSOURI CITY             TX
#
#          Taxpayer Zip  Taxpayer County  Location Number  \
# 2788491       75904.0                3                1
# 2788492       76548.0               14                1
# 2788493       77650.0               84                1
# 2788494       75119.0               70                4
# 2788495       77006.0              101                2
# 2788496       78842.0              233                1
# 2788497       75904.0                3                1
# 2788498       77074.0              101                2
# 2788499       77024.0              101                1
# 2788500       77459.0               79                3
#
#                        Location Name           Location Address  ...  \
# 2788491    TOKYO JAPANESE RESTAURANT     2950 S JOHN REDDITT DR  ...
# 2788492                 TIPSY TOMATO           220 MILLERS XING  ...
# 2788493                   HARD HEADS            1035 HIGHWAY 87  ...
# 2788494  WYNDHAM GARDEN DALLAS NORTH  2645 LYNDON B JOHNSON FWY  ...
# 2788495              LA COLOMBE D'OR         3410 MONTROSE BLVD  ...
# 2788496                     GORZUGIS            317 N CENTER ST  ...
# 2788497    TOKYO JAPANESE RESTAURANT     2950 S JOHN REDDITT DR  ...
# 2788498           HUNAN'S RESTAURANT         3835 BELLAIRE BLVD  ...
# 2788499                  TEXADELPHIA          1228 SEAWALL BLVD  ...
# 2788500          MOCITY SPORTS GRILL         3760 CARTWRIGHT RD  ...
#
#         Inside/Outside City Limits TABC Permit Number  \
# 2788491                          Y           RM832251
# 2788492                          Y          MB1106219
# 2788493                          N           MB895709
# 2788494                          Y           MB814378
# 2788495                          Y           MB126836
# 2788496                          Y          MB1050103
# 2788497                          Y           RM832251
# 2788498                          Y           MB929376
# 2788499                          Y          MB1023962
# 2788500                          Y           MB878899
#
#          Responsibility Begin Date  Responsibility End Date  \
# 2788491                 02/20/2013               08/08/2022
# 2788492                 01/13/2021               07/25/2022
# 2788493                 01/21/2015               07/22/2022
# 2788494                 12/01/2014               07/24/2022
# 2788495                 12/01/1993                      NaN
# 2788496                 04/08/2019               07/26/2022
# 2788497                 02/20/2013               08/08/2022
# 2788498                 12/11/2015                      NaN
# 2788499                 07/24/2018               07/24/2022
# 2788500                 11/01/2016               07/23/2022
#
#         Obligation End Date Liquor Receipts Wine Receipts Beer Receipts  \
# 2788491          06/30/2021               0           425           996
# 2788492          04/30/2021               0             0             0
# 2788493          02/28/2018            4849           151          8398
# 2788494          10/31/2016           32573         13997             0
# 2788495          11/30/2007            5799         31809           802
# 2788496          11/30/2021               0             0             0
# 2788497          06/30/2018               0           955           589
# 2788498          07/31/2022             221           252           101
# 2788499          04/30/2021            8997           934          7974
# 2788500          05/31/2021           24442           566          4396
#
#         Cover Charge Receipts  Total Receipts
# 2788491                     0            1421
# 2788492                     0               0
# 2788493                     0           13398
# 2788494                 52040           98610
# 2788495                     0           38410
# 2788496                     0               0
# 2788497                     0            1544
# 2788498                     0             574
# 2788499                     0           17905
# 2788500                     0           29404
#
# [10 rows x 24 columns]

# %%
x = df[df['Taxpayer Number'] == 32053574318]
x = x.sort_values(by=['Obligation End Date'])
x
# Out:
#          Taxpayer Number         Taxpayer Name    Taxpayer Address  \
# 1941121      32053574318  DBLT ENTERPRISES LLC  3760 CARTWRIGHT RD
# 1627618      32053574318  DBLT ENTERPRISES LLC  3760 CARTWRIGHT RD
# 1207516      32053574318  DBLT ENTERPRISES LLC  3760 CARTWRIGHT RD
# 1054405      32053574318  DBLT ENTERPRISES LLC  3760 CARTWRIGHT RD
# 1242764      32053574318  DBLT ENTERPRISES LLC  3760 CARTWRIGHT RD
# ...                  ...                   ...                 ...
# 2786599      32053574318  DBLT ENTERPRISES LLC  3760 CARTWRIGHT RD
# 2788459      32053574318  DBLT ENTERPRISES LLC  3760 CARTWRIGHT RD
# 2776429      32053574318  DBLT ENTERPRISES LLC  3760 CARTWRIGHT RD
# 2775780      32053574318  DBLT ENTERPRISES LLC  3760 CARTWRIGHT RD
# 2777638      32053574318  DBLT ENTERPRISES LLC  3760 CARTWRIGHT RD
#
#          Taxpayer City Taxpayer State  Taxpayer Zip  Taxpayer County  \
# 1941121  MISSOURI CITY             TX       77459.0               79
# 1627618  MISSOURI CITY             TX       77459.0               79
# 1207516  MISSOURI CITY             TX       77459.0               79
# 1054405  MISSOURI CITY             TX       77459.0               79
# 1242764  MISSOURI CITY             TX       77459.0               79
# ...                ...            ...           ...              ...
# 2786599  MISSOURI CITY             TX       77459.0               79
# 2788459  MISSOURI CITY             TX       77459.0               79
# 2776429  MISSOURI CITY             TX       77459.0               79
# 2775780  MISSOURI CITY             TX       77459.0               79
# 2777638  MISSOURI CITY             TX       77459.0               79
#
#          Location Number          Location Name    Location Address  ...  \
# 1941121                2  ZONE 9 LOUNGE & GRILL  3760 CARTWRIGHT RD  ...
# 1627618                2  ZONE 9 LOUNGE & GRILL  3760 CARTWRIGHT RD  ...
# 1207516                2  ZONE 9 LOUNGE & GRILL  3760 CARTWRIGHT RD  ...
# 1054405                2  ZONE 9 LOUNGE & GRILL  3760 CARTWRIGHT RD  ...
# 1242764                2  ZONE 9 LOUNGE & GRILL  3760 CARTWRIGHT RD  ...
# ...                  ...                    ...                 ...  ...
# 2786599                3    MOCITY SPORTS GRILL  3760 CARTWRIGHT RD  ...
# 2788459                3    MOCITY SPORTS GRILL  3760 CARTWRIGHT RD  ...
# 2776429                3    MOCITY SPORTS GRILL  3760 CARTWRIGHT RD  ...
# 2775780                3    MOCITY SPORTS GRILL  3760 CARTWRIGHT RD  ...
# 2777638                3    MOCITY SPORTS GRILL  3760 CARTWRIGHT RD  ...
#
#         Inside/Outside City Limits TABC Permit Number  \
# 1941121                          Y           MB878899
# 1627618                          Y           MB878899
# 1207516                          Y           MB878899
# 1054405                          Y           MB878899
# 1242764                          Y           MB878899
# ...                            ...                ...
# 2786599                          Y           MB878899
# 2788459                          Y           MB878899
# 2776429                          Y           MB878899
# 2775780                          Y           MB878899
# 2777638                          Y           MB878899
#
#          Responsibility Begin Date  Responsibility End Date  \
# 1941121                 2014-07-23               2016-10-31
# 1627618                 2014-07-23               2016-10-31
# 1207516                 2014-07-23               2016-10-31
# 1054405                 2014-07-23               2016-10-31
# 1242764                 2014-07-23               2016-10-31
# ...                            ...                      ...
# 2786599                 2016-11-01               2022-07-23
# 2788459                 2016-11-01               2022-07-23
# 2776429                 2016-11-01               2022-07-23
# 2775780                 2016-11-01               2022-07-23
# 2777638                 2016-11-01               2022-07-23
#
#         Obligation End Date Liquor Receipts Wine Receipts Beer Receipts  \
# 1941121          2014-07-31            7433           149          2533
# 1627618          2014-08-31           13865           370          4111
# 1207516          2014-09-30           11878           338          5081
# 1054405          2014-10-31           12684           458          5713
# 1242764          2014-11-30           10230           388          3730
# ...                     ...             ...           ...           ...
# 2786599          2022-03-31           19754           520          3409
# 2788459          2022-04-30           19429           482          2721
# 2776429          2022-05-31           19705           289          2595
# 2775780          2022-06-30           22936           389          3461
# 2777638          2022-07-31           25073           556          3657
#
#         Cover Charge Receipts  Total Receipts
# 1941121                     0           10115
# 1627618                     0           18346
# 1207516                     0           17297
# 1054405                     0           18855
# 1242764                     0           14348
# ...                       ...             ...
# 2786599                     0           23683
# 2788459                     0           22632
# 2776429                     0           22589
# 2775780                     0           26786
# 2777638                     0           29286
#
# [97 rows x 24 columns]
